# %% [markdown]
# # Disclaimer:
# **baseline from naver boostcamp, edited by cuffyluv**

# %%
# 모듈 import
import pandas as pd
from collections import Counter
from IPython.display import display

from mmengine.config import Config
from mmengine.runner import Runner
from mmdet.registry import DATASETS
from mmdet.utils import register_all_modules

# %%
# custom 설정
classes = ("General trash", "Paper", "Paper pack", "Metal", "Glass",
           "Plastic", "Styrofoam", "Plastic bag", "Battery", "Clothing")

root = "../../../dataset/"
train_ann = "train.json"
test_ann  = "test.json"

# config file 들고오기
cfg = Config.fromfile("configs/faster_rcnn/faster-rcnn_r50_fpn_1x_coco.py")
register_all_modules(init_default_scope=True)
cfg.default_scope = "mmdet"

# dataset config 수정
for ds_key in ["train_dataloader", "test_dataloader"]:
    if ds_key not in cfg:
        continue
    ds = cfg[ds_key]["dataset"] if "dataset" in cfg[ds_key] else cfg[ds_key]
    ds.metainfo = dict(classes=classes)
    ds.data_root = root
    ds.ann_file = train_ann if ds_key == "train_dataloader" else test_ann
    ds.data_prefix = dict(img="")

cfg.train_dataloader.batch_size = 4
cfg.train_dataloader.num_workers = max(2, cfg.train_dataloader.get("num_workers", 2))
cfg.train_dataloader.dataset.pipeline[2]["scale"] = (512, 512)

cfg.test_dataloader.batch_size = 1
cfg.test_dataloader.num_workers = max(2, cfg.test_dataloader.get("num_workers", 2))
cfg.test_dataloader.dataset.pipeline[1]["scale"] = (512, 512)

# validate 비활성화
for k in ("val_dataloader", "val_evaluator", "val_cfg", "val_loop"):
    cfg.pop(k, None)
cfg.train_cfg = cfg.get("train_cfg", {})
cfg.train_cfg["val_interval"] = 0

# 학습 config 수정
cfg.device = "cuda"
cfg.gpu_ids = [0]
cfg.randomness = dict(seed=2025, deterministic=False)
cfg.work_dir = "./work_dirs/faster_rcnn_r50_fpn_1x_trash"

cfg.model.roi_head.bbox_head.num_classes = len(classes)
cfg.optim_wrapper = {**cfg.get("optim_wrapper", {}), "clip_grad": dict(max_norm=35, norm_type=2)}

cfg.train_cfg.max_epochs = 12
cfg.default_hooks["checkpoint"]["max_keep_ckpts"] = 3
cfg.default_hooks["checkpoint"]["interval"] = 1

# %%
# dataset summarization 확인
train_ds_cfg = cfg.train_dataloader.dataset
train_ds = DATASETS.build(train_ds_cfg)

def summarize_dataset(ds):
    ds.full_init()
    num_images = len(ds)
    classes = list(ds.metainfo.get("classes", []))

    counts = Counter()
    for i in range(num_images):
        info = ds.get_data_info(i)
        for inst in info.get("instances", []):
            lbl = inst.get("bbox_label", None)
            if lbl is not None:
                counts[lbl] += 1

    df = pd.DataFrame({
        "category": [f"{i} [{c}]" for i, c in enumerate(classes)],
        "count": [counts.get(i, 0) for i in range(len(classes))]
    })

    print(f"\n [Info] CocoDataset Train dataset with number of images {num_images}, and instance counts:")
    display(df)

summarize_dataset(train_ds)
# Out:
# loading annotations into memory...
# Done (t=0.08s)
# creating index...
# index created!
#
#  [Info] CocoDataset Train dataset with number of images 4883, and instance counts:
#             category  count
# 0  0 [General trash]   3965
# 1          1 [Paper]   6352
# 2     2 [Paper pack]    897
# 3          3 [Metal]    936
# 4          4 [Glass]    982
# 5        5 [Plastic]   2943
# 6      6 [Styrofoam]   1263
# 7    7 [Plastic bag]   5178
# 8        8 [Battery]    159
# 9       9 [Clothing]    468

# %%
train_ds_cfg = cfg.train_dataloader.dataset
train_ds = DATASETS.build(train_ds_cfg)

# dataset 크기 확인
print(f"[DEBUG] Train dataset length: {len(train_ds)}")

# batch_size 확인
batch_size = cfg.train_dataloader.batch_size
print(f"[DEBUG] train_dataloader.batch_size: {batch_size}")

# drop_last, shuffle 확인
drop_last = cfg.train_dataloader.get('drop_last', False)
shuffle = cfg.train_dataloader.get('shuffle', True)
print(f"[DEBUG] train_dataloader.drop_last: {drop_last}")
print(f"[DEBUG] train_dataloader.shuffle: {shuffle}")

# iteration 수 계산 (epoch 당)
num_samples = len(train_ds)
if drop_last:
    num_iters = num_samples // batch_size
else:
    num_iters = (num_samples + batch_size - 1) // batch_size
print(f"[DEBUG] Expected iterations per epoch: {num_iters}")

# test dataset도 확인
test_ds_cfg = cfg.test_dataloader.dataset
test_ds = DATASETS.build(test_ds_cfg)
print(f"[DEBUG] Test dataset length: {len(test_ds)}")
print(f"[DEBUG] test_dataloader.batch_size: {cfg.test_dataloader.batch_size}")
# Out:
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
# [DEBUG] Train dataset length: 4883
# [DEBUG] train_dataloader.batch_size: 4
# [DEBUG] train_dataloader.drop_last: False
# [DEBUG] train_dataloader.shuffle: True
# [DEBUG] Expected iterations per epoch: 1221
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [DEBUG] Test dataset length: 4871
# [DEBUG] test_dataloader.batch_size: 1

# %%
# 모델 학습
runner = Runner.from_cfg(cfg)
runner.train()
# Out:
# 12/02 22:17:59 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 2025
#     GPU 0: Tesla V100-SXM2-32GB
#     CUDA_HOME: None
#     GCC: n/a
#     PyTorch: 2.1.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.0+cu118
#     OpenCV: 4.7.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 2025
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
# /bin/sh: 1: gcc: not found
# 12/02 22:17:59 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'data/coco/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(interval=1, max_keep_ckpts=3, type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# device = 'cuda'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# gpu_ids = [
#     0,
# ]
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# model = dict(
#     backbone=dict(
#         depth=50,
#         frozen_stages=1,
#         init_cfg=dict(checkpoint='torchvision://resnet50', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNet'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=dict(
#             bbox_coder=dict(
#                 target_means=[
#                     0.0,
#                     0.0,
#                     0.0,
#                     0.0,
#                 ],
#                 target_stds=[
#                     0.1,
#                     0.1,
#                     0.2,
#                     0.2,
#                 ],
#                 type='DeltaXYWHBBoxCoder'),
#             fc_out_channels=1024,
#             in_channels=256,
#             loss_bbox=dict(loss_weight=1.0, type='L1Loss'),
#             loss_cls=dict(
#                 loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#             num_classes=10,
#             reg_class_agnostic=False,
#             roi_feat_size=7,
#             type='Shared2FCBBoxHead'),
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         type='StandardRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(loss_weight=1.0, type='L1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.05),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=dict(
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=False,
#                 min_pos_iou=0.5,
#                 neg_iou_thr=0.5,
#                 pos_iou_thr=0.5,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=True,
#                 neg_pos_ub=-1,
#                 num=512,
#                 pos_fraction=0.25,
#                 type='RandomSampler')),
#         rpn=dict(
#             allowed_border=-1,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=True,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='FasterRCNN')
# optim_wrapper = dict(
#     clip_grad=dict(max_norm=35, norm_type=2),
#     optimizer=dict(lr=0.02, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=12,
#         gamma=0.1,
#         milestones=[
#             8,
#             11,
#         ],
#         type='MultiStepLR'),
# ]
# randomness = dict(deterministic=False, seed=2025)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='test.json',
#         backend_args=None,
#         data_prefix=dict(img=''),
#         data_root='../../dataset/',
#         metainfo=dict(
#             classes=(
#                 'General trash',
#                 'Paper',
#                 'Paper pack',
#                 'Metal',
#                 'Glass',
#                 'Plastic',
#                 'Styrofoam',
#                 'Plastic bag',
#                 'Battery',
#                 'Clothing',
#             )),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 512,
#                 512,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='data/coco/annotations/instances_val2017.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=12, type='EpochBasedTrainLoop', val_interval=0)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=4,
#     dataset=dict(
#         ann_file='train.json',
#         backend_args=None,
#         data_prefix=dict(img=''),
#         data_root='../../dataset/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'General trash',
#                 'Paper',
#                 'Paper pack',
#                 'Metal',
#                 'Glass',
#                 'Plastic',
#                 'Styrofoam',
#                 'Plastic bag',
#                 'Battery',
#                 'Clothing',
#             )),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(keep_ratio=True, scale=(
#                 512,
#                 512,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/faster_rcnn_r50_fpn_1x_trash'
#
# 12/02 22:18:00 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 12/02 22:18:00 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.08s)
# creating index...
# index created!
# 12/02 22:18:01 - mmengine - INFO - load model from: torchvision://resnet50
# 12/02 22:18:01 - mmengine - INFO - Loads checkpoint by torchvision backend from path: torchvision://resnet50
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /data/ephemeral/home/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 12/02 22:18:08 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 12/02 22:18:08 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 12/02 22:18:08 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 12/02 22:18:08 - mmengine - INFO - Checkpoints will be saved to /data/ephemeral/home/jsw/mmdetection/work_dirs/faster_rcnn_r50_fpn_1x_trash.
# 12/02 22:18:18 - mmengine - INFO - Epoch(train)  [1][  50/1221]  lr: 1.9820e-03  eta: 0:49:07  time: 0.2018  data_time: 0.0102  memory: 2019  grad_norm: 6.8811  loss: 1.1449  loss_rpn_cls: 0.4784  loss_rpn_bbox: 0.0626  loss_cls: 0.5121  acc: 93.9453  loss_bbox: 0.0919
# 12/02 22:18:28 - mmengine - INFO - Epoch(train)  [1][ 100/1221]  lr: 3.9840e-03  eta: 0:47:43  time: 0.1917  data_time: 0.0074  memory: 2019  grad_norm: 2.6527  loss: 0.7509  loss_rpn_cls: 0.1522  loss_rpn_bbox: 0.0488  loss_cls: 0.3183  acc: 94.7754  loss_bbox: 0.2316
# 12/02 22:18:37 - mmengine - INFO - Epoch(train)  [1][ 150/1221]  lr: 5.9860e-03  eta: 0:46:55  time: 0.1890  data_time: 0.0068  memory: 2020  grad_norm: 2.6263  loss: 0.7265  loss_rpn_cls: 0.1265  loss_rpn_bbox: 0.0460  loss_cls: 0.3182  acc: 91.0645  loss_bbox: 0.2358
# 12/02 22:18:47 - mmengine - INFO - Epoch(train)  [1][ 200/1221]  lr: 7.9880e-03  eta: 0:46:29  time: 0.1896  data_time: 0.0073  memory: 2020  grad_norm: 2.6669  loss: 0.8003  loss_rpn_cls: 0.1223  loss_rpn_bbox: 0.0459  loss_cls: 0.3498  acc: 95.6055  loss_bbox: 0.2823
# 12/02 22:18:56 - mmengine - INFO - Epoch(train)  [1][ 250/1221]  lr: 9.9900e-03  eta: 0:46:08  time: 0.1890  data_time: 0.0070  memory: 2019  grad_norm: 2.8823  loss: 0.7729  loss_rpn_cls: 0.1183  loss_rpn_bbox: 0.0456  loss_cls: 0.3436  acc: 93.8965  loss_bbox: 0.2654
# 12/02 22:19:06 - mmengine - INFO - Epoch(train)  [1][ 300/1221]  lr: 1.1992e-02  eta: 0:45:53  time: 0.1900  data_time: 0.0070  memory: 2020  grad_norm: 2.5693  loss: 0.7532  loss_rpn_cls: 0.1094  loss_rpn_bbox: 0.0463  loss_cls: 0.3293  acc: 90.5762  loss_bbox: 0.2682
# 12/02 22:19:15 - mmengine - INFO - Epoch(train)  [1][ 350/1221]  lr: 1.3994e-02  eta: 0:45:35  time: 0.1877  data_time: 0.0069  memory: 2020  grad_norm: 2.5740  loss: 0.7871  loss_rpn_cls: 0.1084  loss_rpn_bbox: 0.0446  loss_cls: 0.3641  acc: 95.0684  loss_bbox: 0.2699
# 12/02 22:19:24 - mmengine - INFO - Epoch(train)  [1][ 400/1221]  lr: 1.5996e-02  eta: 0:45:21  time: 0.1889  data_time: 0.0073  memory: 2020  grad_norm: 2.6557  loss: 0.8052  loss_rpn_cls: 0.1344  loss_rpn_bbox: 0.0514  loss_cls: 0.3597  acc: 87.6953  loss_bbox: 0.2597
# 12/02 22:19:34 - mmengine - INFO - Epoch(train)  [1][ 450/1221]  lr: 1.7998e-02  eta: 0:45:06  time: 0.1874  data_time: 0.0067  memory: 2020  grad_norm: 2.7257  loss: 0.7625  loss_rpn_cls: 0.1275  loss_rpn_bbox: 0.0480  loss_cls: 0.3428  acc: 91.9922  loss_bbox: 0.2442
# 12/02 22:19:43 - mmengine - INFO - Epoch(train)  [1][ 500/1221]  lr: 2.0000e-02  eta: 0:44:53  time: 0.1883  data_time: 0.0074  memory: 2019  grad_norm: 3.2323  loss: 0.8932  loss_rpn_cls: 0.1544  loss_rpn_bbox: 0.0580  loss_cls: 0.4074  acc: 97.2656  loss_bbox: 0.2733
# 12/02 22:19:53 - mmengine - INFO - Epoch(train)  [1][ 550/1221]  lr: 2.0000e-02  eta: 0:44:39  time: 0.1865  data_time: 0.0065  memory: 2020  grad_norm: 1.9178  loss: 0.7333  loss_rpn_cls: 0.1064  loss_rpn_bbox: 0.0445  loss_cls: 0.3357  acc: 89.2090  loss_bbox: 0.2466
# 12/02 22:20:02 - mmengine - INFO - Epoch(train)  [1][ 600/1221]  lr: 2.0000e-02  eta: 0:44:24  time: 0.1853  data_time: 0.0063  memory: 2020  grad_norm: 2.0440  loss: 0.8361  loss_rpn_cls: 0.1199  loss_rpn_bbox: 0.0507  loss_cls: 0.3894  acc: 89.7949  loss_bbox: 0.2761
# 12/02 22:20:11 - mmengine - INFO - Epoch(train)  [1][ 650/1221]  lr: 2.0000e-02  eta: 0:44:11  time: 0.1863  data_time: 0.0070  memory: 2020  grad_norm: 2.0096  loss: 0.8267  loss_rpn_cls: 0.1140  loss_rpn_bbox: 0.0559  loss_cls: 0.3802  acc: 87.0605  loss_bbox: 0.2766
# 12/02 22:20:21 - mmengine - INFO - Epoch(train)  [1][ 700/1221]  lr: 2.0000e-02  eta: 0:44:01  time: 0.1889  data_time: 0.0070  memory: 2020  grad_norm: 1.7216  loss: 0.7380  loss_rpn_cls: 0.0956  loss_rpn_bbox: 0.0447  loss_cls: 0.3487  acc: 95.2148  loss_bbox: 0.2490
# 12/02 22:20:30 - mmengine - INFO - Epoch(train)  [1][ 750/1221]  lr: 2.0000e-02  eta: 0:43:49  time: 0.1863  data_time: 0.0067  memory: 2019  grad_norm: 1.6766  loss: 0.6661  loss_rpn_cls: 0.0959  loss_rpn_bbox: 0.0456  loss_cls: 0.3043  acc: 91.3086  loss_bbox: 0.2202
# 12/02 22:20:39 - mmengine - INFO - Epoch(train)  [1][ 800/1221]  lr: 2.0000e-02  eta: 0:43:37  time: 0.1862  data_time: 0.0070  memory: 2020  grad_norm: 1.7704  loss: 0.7028  loss_rpn_cls: 0.0884  loss_rpn_bbox: 0.0397  loss_cls: 0.3298  acc: 88.8672  loss_bbox: 0.2448
# 12/02 22:20:49 - mmengine - INFO - Epoch(train)  [1][ 850/1221]  lr: 2.0000e-02  eta: 0:43:24  time: 0.1856  data_time: 0.0071  memory: 2020  grad_norm: 1.7633  loss: 0.7939  loss_rpn_cls: 0.1005  loss_rpn_bbox: 0.0523  loss_cls: 0.3650  acc: 85.5957  loss_bbox: 0.2760
# 12/02 22:20:58 - mmengine - INFO - Epoch(train)  [1][ 900/1221]  lr: 2.0000e-02  eta: 0:43:14  time: 0.1870  data_time: 0.0071  memory: 2020  grad_norm: 1.8614  loss: 0.7508  loss_rpn_cls: 0.0831  loss_rpn_bbox: 0.0425  loss_cls: 0.3503  acc: 93.8965  loss_bbox: 0.2748
# 12/02 22:21:07 - mmengine - INFO - Epoch(train)  [1][ 950/1221]  lr: 2.0000e-02  eta: 0:43:04  time: 0.1883  data_time: 0.0072  memory: 2020  grad_norm: 2.0007  loss: 0.8189  loss_rpn_cls: 0.1170  loss_rpn_bbox: 0.0545  loss_cls: 0.3818  acc: 94.9707  loss_bbox: 0.2656
# 12/02 22:21:17 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_coco_20251202_221758
# 12/02 22:21:17 - mmengine - INFO - Epoch(train)  [1][1000/1221]  lr: 2.0000e-02  eta: 0:42:54  time: 0.1872  data_time: 0.0066  memory: 2019  grad_norm: 1.8005  loss: 0.7011  loss_rpn_cls: 0.0799  loss_rpn_bbox: 0.0447  loss_cls: 0.3346  acc: 93.9941  loss_bbox: 0.2420
# 12/02 22:21:26 - mmengine - INFO - Epoch(train)  [1][1050/1221]  lr: 2.0000e-02  eta: 0:42:43  time: 0.1860  data_time: 0.0069  memory: 2020  grad_norm: 1.6202  loss: 0.6347  loss_rpn_cls: 0.0691  loss_rpn_bbox: 0.0362  loss_cls: 0.3115  acc: 89.0625  loss_bbox: 0.2180
# 12/02 22:21:35 - mmengine - INFO - Epoch(train)  [1][1100/1221]  lr: 2.0000e-02  eta: 0:42:32  time: 0.1865  data_time: 0.0066  memory: 2020  grad_norm: 1.8905  loss: 0.7343  loss_rpn_cls: 0.0791  loss_rpn_bbox: 0.0420  loss_cls: 0.3537  acc: 91.9434  loss_bbox: 0.2595
# 12/02 22:21:45 - mmengine - INFO - Epoch(train)  [1][1150/1221]  lr: 2.0000e-02  eta: 0:42:22  time: 0.1874  data_time: 0.0067  memory: 2020  grad_norm: 1.9266  loss: 0.7846  loss_rpn_cls: 0.0869  loss_rpn_bbox: 0.0465  loss_cls: 0.3732  acc: 85.2051  loss_bbox: 0.2781
# 12/02 22:21:54 - mmengine - INFO - Epoch(train)  [1][1200/1221]  lr: 2.0000e-02  eta: 0:42:12  time: 0.1866  data_time: 0.0068  memory: 2020  grad_norm: 1.7984  loss: 0.7854  loss_rpn_cls: 0.0813  loss_rpn_bbox: 0.0422  loss_cls: 0.3808  acc: 95.7031  loss_bbox: 0.2811
# 12/02 22:21:58 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_coco_20251202_221758
# 12/02 22:21:58 - mmengine - INFO - Saving checkpoint at 1 epochs
# 12/02 22:22:09 - mmengine - INFO - Epoch(train)  [2][  50/1221]  lr: 2.0000e-02  eta: 0:41:57  time: 0.1872  data_time: 0.0082  memory: 2020  grad_norm: 1.7798  loss: 0.7042  loss_rpn_cls: 0.0682  loss_rpn_bbox: 0.0361  loss_cls: 0.3479  acc: 85.1074  loss_bbox: 0.2520
# 12/02 22:22:18 - mmengine - INFO - Epoch(train)  [2][ 100/1221]  lr: 2.0000e-02  eta: 0:41:47  time: 0.1861  data_time: 0.0068  memory: 2020  grad_norm: 1.7276  loss: 0.6806  loss_rpn_cls: 0.0729  loss_rpn_bbox: 0.0390  loss_cls: 0.3272  acc: 92.1875  loss_bbox: 0.2415
# 12/02 22:22:27 - mmengine - INFO - Epoch(train)  [2][ 150/1221]  lr: 2.0000e-02  eta: 0:41:37  time: 0.1873  data_time: 0.0071  memory: 2020  grad_norm: 1.8585  loss: 0.7277  loss_rpn_cls: 0.0989  loss_rpn_bbox: 0.0440  loss_cls: 0.3447  acc: 90.0879  loss_bbox: 0.2401
# 12/02 22:22:37 - mmengine - INFO - Epoch(train)  [2][ 200/1221]  lr: 2.0000e-02  eta: 0:41:27  time: 0.1867  data_time: 0.0069  memory: 2020  grad_norm: 1.7096  loss: 0.6336  loss_rpn_cls: 0.0627  loss_rpn_bbox: 0.0355  loss_cls: 0.3133  acc: 91.2109  loss_bbox: 0.2220
# 12/02 22:22:46 - mmengine - INFO - Epoch(train)  [2][ 250/1221]  lr: 2.0000e-02  eta: 0:41:16  time: 0.1851  data_time: 0.0069  memory: 2020  grad_norm: 1.6555  loss: 0.6564  loss_rpn_cls: 0.0630  loss_rpn_bbox: 0.0362  loss_cls: 0.3158  acc: 90.2832  loss_bbox: 0.2414
# 12/02 22:22:55 - mmengine - INFO - Epoch(train)  [2][ 300/1221]  lr: 2.0000e-02  eta: 0:41:06  time: 0.1854  data_time: 0.0069  memory: 2020  grad_norm: 1.8274  loss: 0.7010  loss_rpn_cls: 0.0724  loss_rpn_bbox: 0.0416  loss_cls: 0.3279  acc: 91.5039  loss_bbox: 0.2591
# 12/02 22:23:04 - mmengine - INFO - Epoch(train)  [2][ 350/1221]  lr: 2.0000e-02  eta: 0:40:56  time: 0.1862  data_time: 0.0069  memory: 2020  grad_norm: 1.8838  loss: 0.6959  loss_rpn_cls: 0.0700  loss_rpn_bbox: 0.0366  loss_cls: 0.3406  acc: 92.3340  loss_bbox: 0.2487
# 12/02 22:23:14 - mmengine - INFO - Epoch(train)  [2][ 400/1221]  lr: 2.0000e-02  eta: 0:40:46  time: 0.1871  data_time: 0.0070  memory: 2020  grad_norm: 1.8212  loss: 0.7371  loss_rpn_cls: 0.0694  loss_rpn_bbox: 0.0374  loss_cls: 0.3615  acc: 93.4082  loss_bbox: 0.2688
# 12/02 22:23:23 - mmengine - INFO - Epoch(train)  [2][ 450/1221]  lr: 2.0000e-02  eta: 0:40:36  time: 0.1869  data_time: 0.0069  memory: 2019  grad_norm: 1.9008  loss: 0.7419  loss_rpn_cls: 0.0699  loss_rpn_bbox: 0.0494  loss_cls: 0.3497  acc: 87.6465  loss_bbox: 0.2729
# 12/02 22:23:32 - mmengine - INFO - Epoch(train)  [2][ 500/1221]  lr: 2.0000e-02  eta: 0:40:27  time: 0.1876  data_time: 0.0071  memory: 2020  grad_norm: 1.8752  loss: 0.7368  loss_rpn_cls: 0.0731  loss_rpn_bbox: 0.0462  loss_cls: 0.3454  acc: 89.7949  loss_bbox: 0.2721
# 12/02 22:23:42 - mmengine - INFO - Epoch(train)  [2][ 550/1221]  lr: 2.0000e-02  eta: 0:40:17  time: 0.1864  data_time: 0.0068  memory: 2020  grad_norm: 1.6828  loss: 0.6242  loss_rpn_cls: 0.0652  loss_rpn_bbox: 0.0369  loss_cls: 0.2969  acc: 92.0898  loss_bbox: 0.2252
# 12/02 22:23:51 - mmengine - INFO - Epoch(train)  [2][ 600/1221]  lr: 2.0000e-02  eta: 0:40:07  time: 0.1857  data_time: 0.0069  memory: 2020  grad_norm: 1.8821  loss: 0.6644  loss_rpn_cls: 0.0812  loss_rpn_bbox: 0.0413  loss_cls: 0.3194  acc: 94.8242  loss_bbox: 0.2225
# 12/02 22:24:00 - mmengine - INFO - Epoch(train)  [2][ 650/1221]  lr: 2.0000e-02  eta: 0:39:58  time: 0.1876  data_time: 0.0070  memory: 2020  grad_norm: 1.5817  loss: 0.6466  loss_rpn_cls: 0.0603  loss_rpn_bbox: 0.0356  loss_cls: 0.3172  acc: 96.4355  loss_bbox: 0.2334
# 12/02 22:24:10 - mmengine - INFO - Epoch(train)  [2][ 700/1221]  lr: 2.0000e-02  eta: 0:39:48  time: 0.1865  data_time: 0.0067  memory: 2020  grad_norm: 1.9089  loss: 0.7558  loss_rpn_cls: 0.0857  loss_rpn_bbox: 0.0483  loss_cls: 0.3584  acc: 88.8672  loss_bbox: 0.2634
# 12/02 22:24:19 - mmengine - INFO - Epoch(train)  [2][ 750/1221]  lr: 2.0000e-02  eta: 0:39:38  time: 0.1855  data_time: 0.0065  memory: 2020  grad_norm: 1.8383  loss: 0.6978  loss_rpn_cls: 0.0842  loss_rpn_bbox: 0.0444  loss_cls: 0.3235  acc: 95.2148  loss_bbox: 0.2457
# 12/02 22:24:24 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_coco_20251202_221758
# 12/02 22:24:28 - mmengine - INFO - Epoch(train)  [2][ 800/1221]  lr: 2.0000e-02  eta: 0:39:28  time: 0.1854  data_time: 0.0066  memory: 2019  grad_norm: 1.8173  loss: 0.7522  loss_rpn_cls: 0.0804  loss_rpn_bbox: 0.0463  loss_cls: 0.3570  acc: 89.0137  loss_bbox: 0.2685
# 12/02 22:24:38 - mmengine - INFO - Epoch(train)  [2][ 850/1221]  lr: 2.0000e-02  eta: 0:39:18  time: 0.1845  data_time: 0.0069  memory: 2019  grad_norm: 1.7375  loss: 0.6775  loss_rpn_cls: 0.0638  loss_rpn_bbox: 0.0424  loss_cls: 0.3308  acc: 87.3535  loss_bbox: 0.2405
# 12/02 22:24:47 - mmengine - INFO - Epoch(train)  [2][ 900/1221]  lr: 2.0000e-02  eta: 0:39:07  time: 0.1844  data_time: 0.0065  memory: 2020  grad_norm: 1.8616  loss: 0.6705  loss_rpn_cls: 0.0764  loss_rpn_bbox: 0.0415  loss_cls: 0.3189  acc: 91.0156  loss_bbox: 0.2338
# 12/02 22:24:56 - mmengine - INFO - Epoch(train)  [2][ 950/1221]  lr: 2.0000e-02  eta: 0:38:58  time: 0.1870  data_time: 0.0067  memory: 2019  grad_norm: 1.6649  loss: 0.5859  loss_rpn_cls: 0.0585  loss_rpn_bbox: 0.0343  loss_cls: 0.2841  acc: 87.6953  loss_bbox: 0.2091
# 12/02 22:25:05 - mmengine - INFO - Epoch(train)  [2][1000/1221]  lr: 2.0000e-02  eta: 0:38:48  time: 0.1855  data_time: 0.0068  memory: 2019  grad_norm: 1.7397  loss: 0.6698  loss_rpn_cls: 0.0762  loss_rpn_bbox: 0.0386  loss_cls: 0.3204  acc: 92.2363  loss_bbox: 0.2346
# 12/02 22:25:15 - mmengine - INFO - Epoch(train)  [2][1050/1221]  lr: 2.0000e-02  eta: 0:38:38  time: 0.1855  data_time: 0.0069  memory: 2020  grad_norm: 1.7858  loss: 0.6044  loss_rpn_cls: 0.0691  loss_rpn_bbox: 0.0369  loss_cls: 0.2880  acc: 92.2852  loss_bbox: 0.2104
# 12/02 22:25:24 - mmengine - INFO - Epoch(train)  [2][1100/1221]  lr: 2.0000e-02  eta: 0:38:28  time: 0.1851  data_time: 0.0067  memory: 2020  grad_norm: 1.6345  loss: 0.6188  loss_rpn_cls: 0.0593  loss_rpn_bbox: 0.0315  loss_cls: 0.3098  acc: 90.8203  loss_bbox: 0.2182
# 12/02 22:25:33 - mmengine - INFO - Epoch(train)  [2][1150/1221]  lr: 2.0000e-02  eta: 0:38:18  time: 0.1857  data_time: 0.0066  memory: 2020  grad_norm: 1.6399  loss: 0.5866  loss_rpn_cls: 0.0533  loss_rpn_bbox: 0.0287  loss_cls: 0.2892  acc: 89.5996  loss_bbox: 0.2154
# 12/02 22:25:43 - mmengine - INFO - Epoch(train)  [2][1200/1221]  lr: 2.0000e-02  eta: 0:38:09  time: 0.1863  data_time: 0.0069  memory: 2020  grad_norm: 1.7766  loss: 0.7658  loss_rpn_cls: 0.0785  loss_rpn_bbox: 0.0595  loss_cls: 0.3473  acc: 87.2559  loss_bbox: 0.2806
# 12/02 22:25:46 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_coco_20251202_221758
# 12/02 22:25:46 - mmengine - INFO - Saving checkpoint at 2 epochs
# 12/02 22:25:57 - mmengine - INFO - Epoch(train)  [3][  50/1221]  lr: 2.0000e-02  eta: 0:37:56  time: 0.1918  data_time: 0.0082  memory: 2020  grad_norm: 1.7627  loss: 0.6719  loss_rpn_cls: 0.0591  loss_rpn_bbox: 0.0376  loss_cls: 0.3263  acc: 86.0840  loss_bbox: 0.2490
# 12/02 22:26:06 - mmengine - INFO - Epoch(train)  [3][ 100/1221]  lr: 2.0000e-02  eta: 0:37:47  time: 0.1854  data_time: 0.0069  memory: 2020  grad_norm: 1.8749  loss: 0.6880  loss_rpn_cls: 0.0643  loss_rpn_bbox: 0.0415  loss_cls: 0.3323  acc: 88.2324  loss_bbox: 0.2499
# 12/02 22:26:16 - mmengine - INFO - Epoch(train)  [3][ 150/1221]  lr: 2.0000e-02  eta: 0:37:37  time: 0.1874  data_time: 0.0070  memory: 2020  grad_norm: 1.6917  loss: 0.6234  loss_rpn_cls: 0.0558  loss_rpn_bbox: 0.0335  loss_cls: 0.3015  acc: 96.3867  loss_bbox: 0.2326
# 12/02 22:26:25 - mmengine - INFO - Epoch(train)  [3][ 200/1221]  lr: 2.0000e-02  eta: 0:37:28  time: 0.1863  data_time: 0.0071  memory: 2020  grad_norm: 1.7665  loss: 0.6257  loss_rpn_cls: 0.0572  loss_rpn_bbox: 0.0343  loss_cls: 0.3058  acc: 86.4258  loss_bbox: 0.2284
# 12/02 22:26:34 - mmengine - INFO - Epoch(train)  [3][ 250/1221]  lr: 2.0000e-02  eta: 0:37:18  time: 0.1843  data_time: 0.0069  memory: 2020  grad_norm: 1.6735  loss: 0.5977  loss_rpn_cls: 0.0577  loss_rpn_bbox: 0.0352  loss_cls: 0.2864  acc: 93.7988  loss_bbox: 0.2183
# 12/02 22:26:44 - mmengine - INFO - Epoch(train)  [3][ 300/1221]  lr: 2.0000e-02  eta: 0:37:08  time: 0.1853  data_time: 0.0071  memory: 2020  grad_norm: 1.8506  loss: 0.6618  loss_rpn_cls: 0.0600  loss_rpn_bbox: 0.0396  loss_cls: 0.3257  acc: 95.5566  loss_bbox: 0.2365
# 12/02 22:26:53 - mmengine - INFO - Epoch(train)  [3][ 350/1221]  lr: 2.0000e-02  eta: 0:36:58  time: 0.1868  data_time: 0.0072  memory: 2020  grad_norm: 1.9521  loss: 0.6442  loss_rpn_cls: 0.0615  loss_rpn_bbox: 0.0374  loss_cls: 0.3165  acc: 89.5996  loss_bbox: 0.2288
# 12/02 22:27:02 - mmengine - INFO - Epoch(train)  [3][ 400/1221]  lr: 2.0000e-02  eta: 0:36:49  time: 0.1847  data_time: 0.0069  memory: 2020  grad_norm: 1.7168  loss: 0.6353  loss_rpn_cls: 0.0689  loss_rpn_bbox: 0.0418  loss_cls: 0.3045  acc: 92.5781  loss_bbox: 0.2201
# 12/02 22:27:12 - mmengine - INFO - Epoch(train)  [3][ 450/1221]  lr: 2.0000e-02  eta: 0:36:40  time: 0.1887  data_time: 0.0071  memory: 2020  grad_norm: 1.8167  loss: 0.6498  loss_rpn_cls: 0.0649  loss_rpn_bbox: 0.0367  loss_cls: 0.3181  acc: 88.7695  loss_bbox: 0.2301
# 12/02 22:27:21 - mmengine - INFO - Epoch(train)  [3][ 500/1221]  lr: 2.0000e-02  eta: 0:36:30  time: 0.1868  data_time: 0.0070  memory: 2020  grad_norm: 1.7032  loss: 0.6138  loss_rpn_cls: 0.0573  loss_rpn_bbox: 0.0376  loss_cls: 0.2927  acc: 83.0566  loss_bbox: 0.2262
# 12/02 22:27:30 - mmengine - INFO - Epoch(train)  [3][ 550/1221]  lr: 2.0000e-02  eta: 0:36:21  time: 0.1861  data_time: 0.0068  memory: 2019  grad_norm: 1.7213  loss: 0.5721  loss_rpn_cls: 0.0610  loss_rpn_bbox: 0.0347  loss_cls: 0.2763  acc: 88.3789  loss_bbox: 0.2002
# 12/02 22:27:32 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_coco_20251202_221758
# 12/02 22:27:40 - mmengine - INFO - Epoch(train)  [3][ 600/1221]  lr: 2.0000e-02  eta: 0:36:11  time: 0.1851  data_time: 0.0069  memory: 2020  grad_norm: 1.7397  loss: 0.6617  loss_rpn_cls: 0.0655  loss_rpn_bbox: 0.0392  loss_cls: 0.3119  acc: 89.3555  loss_bbox: 0.2451
# 12/02 22:27:49 - mmengine - INFO - Epoch(train)  [3][ 650/1221]  lr: 2.0000e-02  eta: 0:36:01  time: 0.1858  data_time: 0.0069  memory: 2020  grad_norm: 1.7081  loss: 0.6745  loss_rpn_cls: 0.0607  loss_rpn_bbox: 0.0377  loss_cls: 0.3269  acc: 96.7773  loss_bbox: 0.2492
# 12/02 22:27:58 - mmengine - INFO - Epoch(train)  [3][ 700/1221]  lr: 2.0000e-02  eta: 0:35:52  time: 0.1865  data_time: 0.0071  memory: 2020  grad_norm: 1.8054  loss: 0.6647  loss_rpn_cls: 0.0595  loss_rpn_bbox: 0.0393  loss_cls: 0.3231  acc: 93.4570  loss_bbox: 0.2429
# 12/02 22:28:08 - mmengine - INFO - Epoch(train)  [3][ 750/1221]  lr: 2.0000e-02  eta: 0:35:43  time: 0.1870  data_time: 0.0068  memory: 2020  grad_norm: 1.6941  loss: 0.5932  loss_rpn_cls: 0.0547  loss_rpn_bbox: 0.0318  loss_cls: 0.2937  acc: 93.9941  loss_bbox: 0.2130
# 12/02 22:28:17 - mmengine - INFO - Epoch(train)  [3][ 800/1221]  lr: 2.0000e-02  eta: 0:35:33  time: 0.1868  data_time: 0.0070  memory: 2020  grad_norm: 1.7584  loss: 0.6481  loss_rpn_cls: 0.0611  loss_rpn_bbox: 0.0360  loss_cls: 0.3190  acc: 95.2148  loss_bbox: 0.2320
# 12/02 22:28:26 - mmengine - INFO - Epoch(train)  [3][ 850/1221]  lr: 2.0000e-02  eta: 0:35:24  time: 0.1855  data_time: 0.0068  memory: 2019  grad_norm: 1.7108  loss: 0.6161  loss_rpn_cls: 0.0599  loss_rpn_bbox: 0.0407  loss_cls: 0.2954  acc: 91.7480  loss_bbox: 0.2200
# 12/02 22:28:36 - mmengine - INFO - Epoch(train)  [3][ 900/1221]  lr: 2.0000e-02  eta: 0:35:14  time: 0.1874  data_time: 0.0069  memory: 2019  grad_norm: 1.7653  loss: 0.6509  loss_rpn_cls: 0.0545  loss_rpn_bbox: 0.0345  loss_cls: 0.3175  acc: 88.6230  loss_bbox: 0.2445
# 12/02 22:28:45 - mmengine - INFO - Epoch(train)  [3][ 950/1221]  lr: 2.0000e-02  eta: 0:35:05  time: 0.1852  data_time: 0.0067  memory: 2019  grad_norm: 1.8331  loss: 0.6754  loss_rpn_cls: 0.0577  loss_rpn_bbox: 0.0384  loss_cls: 0.3255  acc: 82.7637  loss_bbox: 0.2538
# 12/02 22:28:54 - mmengine - INFO - Epoch(train)  [3][1000/1221]  lr: 2.0000e-02  eta: 0:34:55  time: 0.1858  data_time: 0.0068  memory: 2019  grad_norm: 1.6731  loss: 0.6102  loss_rpn_cls: 0.0592  loss_rpn_bbox: 0.0379  loss_cls: 0.2875  acc: 93.2617  loss_bbox: 0.2256
# 12/02 22:29:03 - mmengine - INFO - Epoch(train)  [3][1050/1221]  lr: 2.0000e-02  eta: 0:34:46  time: 0.1859  data_time: 0.0071  memory: 2019  grad_norm: 1.7688  loss: 0.6138  loss_rpn_cls: 0.0634  loss_rpn_bbox: 0.0383  loss_cls: 0.2876  acc: 85.8398  loss_bbox: 0.2246
# 12/02 22:29:13 - mmengine - INFO - Epoch(train)  [3][1100/1221]  lr: 2.0000e-02  eta: 0:34:36  time: 0.1859  data_time: 0.0069  memory: 2020  grad_norm: 1.7594  loss: 0.6429  loss_rpn_cls: 0.0664  loss_rpn_bbox: 0.0421  loss_cls: 0.3082  acc: 90.1367  loss_bbox: 0.2263
# 12/02 22:29:22 - mmengine - INFO - Epoch(train)  [3][1150/1221]  lr: 2.0000e-02  eta: 0:34:26  time: 0.1849  data_time: 0.0067  memory: 2020  grad_norm: 1.7443  loss: 0.5994  loss_rpn_cls: 0.0629  loss_rpn_bbox: 0.0383  loss_cls: 0.2819  acc: 92.6758  loss_bbox: 0.2163
# 12/02 22:29:31 - mmengine - INFO - Epoch(train)  [3][1200/1221]  lr: 2.0000e-02  eta: 0:34:17  time: 0.1870  data_time: 0.0067  memory: 2020  grad_norm: 1.7431  loss: 0.6418  loss_rpn_cls: 0.0620  loss_rpn_bbox: 0.0365  loss_cls: 0.3133  acc: 91.2109  loss_bbox: 0.2299
# 12/02 22:29:35 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_coco_20251202_221758
# 12/02 22:29:35 - mmengine - INFO - Saving checkpoint at 3 epochs
# 12/02 22:29:46 - mmengine - INFO - Epoch(train)  [4][  50/1221]  lr: 2.0000e-02  eta: 0:34:04  time: 0.1882  data_time: 0.0081  memory: 2020  grad_norm: 1.8252  loss: 0.6201  loss_rpn_cls: 0.0695  loss_rpn_bbox: 0.0387  loss_cls: 0.2976  acc: 93.0664  loss_bbox: 0.2143
# 12/02 22:29:55 - mmengine - INFO - Epoch(train)  [4][ 100/1221]  lr: 2.0000e-02  eta: 0:33:54  time: 0.1862  data_time: 0.0069  memory: 2020  grad_norm: 1.6883  loss: 0.5936  loss_rpn_cls: 0.0485  loss_rpn_bbox: 0.0370  loss_cls: 0.2844  acc: 95.5078  loss_bbox: 0.2236
# 12/02 22:30:04 - mmengine - INFO - Epoch(train)  [4][ 150/1221]  lr: 2.0000e-02  eta: 0:33:45  time: 0.1854  data_time: 0.0070  memory: 2020  grad_norm: 1.7665  loss: 0.5992  loss_rpn_cls: 0.0507  loss_rpn_bbox: 0.0345  loss_cls: 0.2866  acc: 92.0898  loss_bbox: 0.2273
# 12/02 22:30:14 - mmengine - INFO - Epoch(train)  [4][ 200/1221]  lr: 2.0000e-02  eta: 0:33:35  time: 0.1863  data_time: 0.0067  memory: 2020  grad_norm: 1.5677  loss: 0.4985  loss_rpn_cls: 0.0413  loss_rpn_bbox: 0.0251  loss_cls: 0.2451  acc: 94.2871  loss_bbox: 0.1869
# 12/02 22:30:23 - mmengine - INFO - Epoch(train)  [4][ 250/1221]  lr: 2.0000e-02  eta: 0:33:26  time: 0.1871  data_time: 0.0068  memory: 2020  grad_norm: 1.7381  loss: 0.5819  loss_rpn_cls: 0.0492  loss_rpn_bbox: 0.0303  loss_cls: 0.2841  acc: 82.1289  loss_bbox: 0.2183
# 12/02 22:30:32 - mmengine - INFO - Epoch(train)  [4][ 300/1221]  lr: 2.0000e-02  eta: 0:33:16  time: 0.1848  data_time: 0.0069  memory: 2020  grad_norm: 1.7741  loss: 0.6016  loss_rpn_cls: 0.0477  loss_rpn_bbox: 0.0356  loss_cls: 0.2921  acc: 92.9199  loss_bbox: 0.2262
# 12/02 22:30:39 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_coco_20251202_221758
# 12/02 22:30:42 - mmengine - INFO - Epoch(train)  [4][ 350/1221]  lr: 2.0000e-02  eta: 0:33:07  time: 0.1871  data_time: 0.0071  memory: 2020  grad_norm: 1.6539  loss: 0.5672  loss_rpn_cls: 0.0500  loss_rpn_bbox: 0.0362  loss_cls: 0.2692  acc: 95.1172  loss_bbox: 0.2118
# 12/02 22:30:51 - mmengine - INFO - Epoch(train)  [4][ 400/1221]  lr: 2.0000e-02  eta: 0:32:58  time: 0.1864  data_time: 0.0072  memory: 2019  grad_norm: 1.7447  loss: 0.5804  loss_rpn_cls: 0.0559  loss_rpn_bbox: 0.0347  loss_cls: 0.2813  acc: 88.6230  loss_bbox: 0.2084
# 12/02 22:31:00 - mmengine - INFO - Epoch(train)  [4][ 450/1221]  lr: 2.0000e-02  eta: 0:32:48  time: 0.1863  data_time: 0.0071  memory: 2019  grad_norm: 1.8777  loss: 0.6243  loss_rpn_cls: 0.0569  loss_rpn_bbox: 0.0431  loss_cls: 0.2882  acc: 88.8672  loss_bbox: 0.2362
# 12/02 22:31:10 - mmengine - INFO - Epoch(train)  [4][ 500/1221]  lr: 2.0000e-02  eta: 0:32:39  time: 0.1861  data_time: 0.0071  memory: 2020  grad_norm: 1.7780  loss: 0.6141  loss_rpn_cls: 0.0575  loss_rpn_bbox: 0.0380  loss_cls: 0.2936  acc: 91.6504  loss_bbox: 0.2250
# 12/02 22:31:19 - mmengine - INFO - Epoch(train)  [4][ 550/1221]  lr: 2.0000e-02  eta: 0:32:29  time: 0.1848  data_time: 0.0069  memory: 2019  grad_norm: 1.7582  loss: 0.6045  loss_rpn_cls: 0.0509  loss_rpn_bbox: 0.0325  loss_cls: 0.3007  acc: 93.6523  loss_bbox: 0.2204
# 12/02 22:31:28 - mmengine - INFO - Epoch(train)  [4][ 600/1221]  lr: 2.0000e-02  eta: 0:32:20  time: 0.1838  data_time: 0.0067  memory: 2020  grad_norm: 1.8239  loss: 0.6623  loss_rpn_cls: 0.0650  loss_rpn_bbox: 0.0397  loss_cls: 0.3101  acc: 91.5527  loss_bbox: 0.2475
# 12/02 22:31:37 - mmengine - INFO - Epoch(train)  [4][ 650/1221]  lr: 2.0000e-02  eta: 0:32:10  time: 0.1870  data_time: 0.0071  memory: 2019  grad_norm: 1.8601  loss: 0.6188  loss_rpn_cls: 0.0505  loss_rpn_bbox: 0.0360  loss_cls: 0.2972  acc: 91.0156  loss_bbox: 0.2351
# 12/02 22:31:47 - mmengine - INFO - Epoch(train)  [4][ 700/1221]  lr: 2.0000e-02  eta: 0:32:01  time: 0.1858  data_time: 0.0069  memory: 2020  grad_norm: 1.7650  loss: 0.5221  loss_rpn_cls: 0.0449  loss_rpn_bbox: 0.0281  loss_cls: 0.2603  acc: 95.0195  loss_bbox: 0.1889
# 12/02 22:31:56 - mmengine - INFO - Epoch(train)  [4][ 750/1221]  lr: 2.0000e-02  eta: 0:31:51  time: 0.1857  data_time: 0.0068  memory: 2020  grad_norm: 1.7269  loss: 0.5552  loss_rpn_cls: 0.0464  loss_rpn_bbox: 0.0308  loss_cls: 0.2693  acc: 92.5781  loss_bbox: 0.2087
# 12/02 22:32:05 - mmengine - INFO - Epoch(train)  [4][ 800/1221]  lr: 2.0000e-02  eta: 0:31:42  time: 0.1856  data_time: 0.0068  memory: 2020  grad_norm: 1.7605  loss: 0.6216  loss_rpn_cls: 0.0534  loss_rpn_bbox: 0.0359  loss_cls: 0.2960  acc: 90.0391  loss_bbox: 0.2363
# 12/02 22:32:14 - mmengine - INFO - Epoch(train)  [4][ 850/1221]  lr: 2.0000e-02  eta: 0:31:33  time: 0.1861  data_time: 0.0068  memory: 2020  grad_norm: 1.7590  loss: 0.6267  loss_rpn_cls: 0.0549  loss_rpn_bbox: 0.0392  loss_cls: 0.2958  acc: 94.3848  loss_bbox: 0.2368
# 12/02 22:32:24 - mmengine - INFO - Epoch(train)  [4][ 900/1221]  lr: 2.0000e-02  eta: 0:31:23  time: 0.1877  data_time: 0.0072  memory: 2020  grad_norm: 1.6784  loss: 0.5626  loss_rpn_cls: 0.0460  loss_rpn_bbox: 0.0341  loss_cls: 0.2841  acc: 92.7734  loss_bbox: 0.1984
# 12/02 22:32:33 - mmengine - INFO - Epoch(train)  [4][ 950/1221]  lr: 2.0000e-02  eta: 0:31:14  time: 0.1876  data_time: 0.0073  memory: 2020  grad_norm: 1.8739  loss: 0.6396  loss_rpn_cls: 0.0569  loss_rpn_bbox: 0.0371  loss_cls: 0.3074  acc: 89.8926  loss_bbox: 0.2383
# 12/02 22:32:43 - mmengine - INFO - Epoch(train)  [4][1000/1221]  lr: 2.0000e-02  eta: 0:31:05  time: 0.1866  data_time: 0.0071  memory: 2019  grad_norm: 1.8484  loss: 0.5802  loss_rpn_cls: 0.0534  loss_rpn_bbox: 0.0311  loss_cls: 0.2910  acc: 91.4551  loss_bbox: 0.2047
# 12/02 22:32:52 - mmengine - INFO - Epoch(train)  [4][1050/1221]  lr: 2.0000e-02  eta: 0:30:55  time: 0.1853  data_time: 0.0068  memory: 2020  grad_norm: 1.6376  loss: 0.5599  loss_rpn_cls: 0.0463  loss_rpn_bbox: 0.0321  loss_cls: 0.2749  acc: 92.6758  loss_bbox: 0.2065
# 12/02 22:33:01 - mmengine - INFO - Epoch(train)  [4][1100/1221]  lr: 2.0000e-02  eta: 0:30:46  time: 0.1857  data_time: 0.0069  memory: 2020  grad_norm: 1.8825  loss: 0.6250  loss_rpn_cls: 0.0618  loss_rpn_bbox: 0.0404  loss_cls: 0.3007  acc: 89.9414  loss_bbox: 0.2222
# 12/02 22:33:10 - mmengine - INFO - Epoch(train)  [4][1150/1221]  lr: 2.0000e-02  eta: 0:30:36  time: 0.1843  data_time: 0.0068  memory: 2019  grad_norm: 1.8345  loss: 0.6706  loss_rpn_cls: 0.0671  loss_rpn_bbox: 0.0498  loss_cls: 0.3149  acc: 93.3594  loss_bbox: 0.2388
# 12/02 22:33:20 - mmengine - INFO - Epoch(train)  [4][1200/1221]  lr: 2.0000e-02  eta: 0:30:27  time: 0.1856  data_time: 0.0069  memory: 2019  grad_norm: 1.7654  loss: 0.5867  loss_rpn_cls: 0.0607  loss_rpn_bbox: 0.0384  loss_cls: 0.2850  acc: 92.4805  loss_bbox: 0.2026
# 12/02 22:33:23 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_coco_20251202_221758
# 12/02 22:33:23 - mmengine - INFO - Saving checkpoint at 4 epochs
# 12/02 22:33:34 - mmengine - INFO - Epoch(train)  [5][  50/1221]  lr: 2.0000e-02  eta: 0:30:13  time: 0.1869  data_time: 0.0085  memory: 2020  grad_norm: 1.7208  loss: 0.5470  loss_rpn_cls: 0.0430  loss_rpn_bbox: 0.0297  loss_cls: 0.2688  acc: 96.2891  loss_bbox: 0.2056
# 12/02 22:33:43 - mmengine - INFO - Epoch(train)  [5][ 100/1221]  lr: 2.0000e-02  eta: 0:30:04  time: 0.1857  data_time: 0.0073  memory: 2020  grad_norm: 1.8088  loss: 0.6095  loss_rpn_cls: 0.0458  loss_rpn_bbox: 0.0375  loss_cls: 0.2947  acc: 89.7949  loss_bbox: 0.2315
# 12/02 22:33:46 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_coco_20251202_221758
# 12/02 22:33:53 - mmengine - INFO - Epoch(train)  [5][ 150/1221]  lr: 2.0000e-02  eta: 0:29:55  time: 0.1850  data_time: 0.0069  memory: 2020  grad_norm: 1.7939  loss: 0.5773  loss_rpn_cls: 0.0542  loss_rpn_bbox: 0.0358  loss_cls: 0.2793  acc: 89.2090  loss_bbox: 0.2080
# 12/02 22:34:02 - mmengine - INFO - Epoch(train)  [5][ 200/1221]  lr: 2.0000e-02  eta: 0:29:45  time: 0.1830  data_time: 0.0066  memory: 2019  grad_norm: 1.8120  loss: 0.5747  loss_rpn_cls: 0.0531  loss_rpn_bbox: 0.0347  loss_cls: 0.2714  acc: 85.5957  loss_bbox: 0.2155
# 12/02 22:34:11 - mmengine - INFO - Epoch(train)  [5][ 250/1221]  lr: 2.0000e-02  eta: 0:29:35  time: 0.1845  data_time: 0.0067  memory: 2019  grad_norm: 1.6830  loss: 0.5582  loss_rpn_cls: 0.0471  loss_rpn_bbox: 0.0311  loss_cls: 0.2718  acc: 91.7969  loss_bbox: 0.2082
# 12/02 22:34:20 - mmengine - INFO - Epoch(train)  [5][ 300/1221]  lr: 2.0000e-02  eta: 0:29:26  time: 0.1846  data_time: 0.0072  memory: 2020  grad_norm: 1.9676  loss: 0.5770  loss_rpn_cls: 0.0476  loss_rpn_bbox: 0.0349  loss_cls: 0.2767  acc: 91.1621  loss_bbox: 0.2179
# 12/02 22:34:29 - mmengine - INFO - Epoch(train)  [5][ 350/1221]  lr: 2.0000e-02  eta: 0:29:16  time: 0.1847  data_time: 0.0073  memory: 2019  grad_norm: 1.7421  loss: 0.6020  loss_rpn_cls: 0.0473  loss_rpn_bbox: 0.0384  loss_cls: 0.2933  acc: 90.5273  loss_bbox: 0.2230
# 12/02 22:34:39 - mmengine - INFO - Epoch(train)  [5][ 400/1221]  lr: 2.0000e-02  eta: 0:29:07  time: 0.1852  data_time: 0.0070  memory: 2019  grad_norm: 1.8013  loss: 0.5274  loss_rpn_cls: 0.0444  loss_rpn_bbox: 0.0305  loss_cls: 0.2583  acc: 95.6055  loss_bbox: 0.1941
# 12/02 22:34:48 - mmengine - INFO - Epoch(train)  [5][ 450/1221]  lr: 2.0000e-02  eta: 0:28:58  time: 0.1857  data_time: 0.0069  memory: 2020  grad_norm: 1.7488  loss: 0.5315  loss_rpn_cls: 0.0422  loss_rpn_bbox: 0.0287  loss_cls: 0.2614  acc: 97.5586  loss_bbox: 0.1992
# 12/02 22:34:57 - mmengine - INFO - Epoch(train)  [5][ 500/1221]  lr: 2.0000e-02  eta: 0:28:48  time: 0.1856  data_time: 0.0069  memory: 2020  grad_norm: 1.7958  loss: 0.5472  loss_rpn_cls: 0.0446  loss_rpn_bbox: 0.0308  loss_cls: 0.2654  acc: 93.7500  loss_bbox: 0.2065
# 12/02 22:35:07 - mmengine - INFO - Epoch(train)  [5][ 550/1221]  lr: 2.0000e-02  eta: 0:28:39  time: 0.1866  data_time: 0.0070  memory: 2020  grad_norm: 1.7624  loss: 0.5956  loss_rpn_cls: 0.0552  loss_rpn_bbox: 0.0363  loss_cls: 0.2882  acc: 90.5273  loss_bbox: 0.2159
# 12/02 22:35:16 - mmengine - INFO - Epoch(train)  [5][ 600/1221]  lr: 2.0000e-02  eta: 0:28:29  time: 0.1861  data_time: 0.0067  memory: 2020  grad_norm: 1.8177  loss: 0.6054  loss_rpn_cls: 0.0532  loss_rpn_bbox: 0.0350  loss_cls: 0.2880  acc: 92.8223  loss_bbox: 0.2292
# 12/02 22:35:25 - mmengine - INFO - Epoch(train)  [5][ 650/1221]  lr: 2.0000e-02  eta: 0:28:20  time: 0.1851  data_time: 0.0069  memory: 2019  grad_norm: 1.7707  loss: 0.5754  loss_rpn_cls: 0.0443  loss_rpn_bbox: 0.0367  loss_cls: 0.2734  acc: 84.5703  loss_bbox: 0.2211
# 12/02 22:35:34 - mmengine - INFO - Epoch(train)  [5][ 700/1221]  lr: 2.0000e-02  eta: 0:28:11  time: 0.1848  data_time: 0.0072  memory: 2019  grad_norm: 1.7940  loss: 0.5475  loss_rpn_cls: 0.0517  loss_rpn_bbox: 0.0373  loss_cls: 0.2587  acc: 95.3613  loss_bbox: 0.1998
# 12/02 22:35:44 - mmengine - INFO - Epoch(train)  [5][ 750/1221]  lr: 2.0000e-02  eta: 0:28:01  time: 0.1877  data_time: 0.0076  memory: 2020  grad_norm: 1.7631  loss: 0.5747  loss_rpn_cls: 0.0416  loss_rpn_bbox: 0.0333  loss_cls: 0.2843  acc: 89.4531  loss_bbox: 0.2155
# 12/02 22:35:53 - mmengine - INFO - Epoch(train)  [5][ 800/1221]  lr: 2.0000e-02  eta: 0:27:52  time: 0.1861  data_time: 0.0071  memory: 2020  grad_norm: 1.9461  loss: 0.5811  loss_rpn_cls: 0.0481  loss_rpn_bbox: 0.0354  loss_cls: 0.2792  acc: 92.0898  loss_bbox: 0.2184
# ...
# 12/02 23:02:55 - mmengine - INFO - Epoch(train) [12][ 900/1221]  lr: 2.0000e-04  eta: 0:00:59  time: 0.1877  data_time: 0.0072  memory: 2020  grad_norm: 1.8664  loss: 0.3849  loss_rpn_cls: 0.0185  loss_rpn_bbox: 0.0238  loss_cls: 0.1725  acc: 94.2871  loss_bbox: 0.1701
# 12/02 23:03:04 - mmengine - INFO - Epoch(train) [12][ 950/1221]  lr: 2.0000e-04  eta: 0:00:50  time: 0.1872  data_time: 0.0070  memory: 2020  grad_norm: 1.7341  loss: 0.3366  loss_rpn_cls: 0.0150  loss_rpn_bbox: 0.0211  loss_cls: 0.1508  acc: 95.1172  loss_bbox: 0.1498
# 12/02 23:03:13 - mmengine - INFO - Epoch(train) [12][1000/1221]  lr: 2.0000e-04  eta: 0:00:41  time: 0.1873  data_time: 0.0071  memory: 2020  grad_norm: 1.8551  loss: 0.4020  loss_rpn_cls: 0.0200  loss_rpn_bbox: 0.0285  loss_cls: 0.1783  acc: 97.5098  loss_bbox: 0.1751
# 12/02 23:03:23 - mmengine - INFO - Epoch(train) [12][1050/1221]  lr: 2.0000e-04  eta: 0:00:31  time: 0.1878  data_time: 0.0070  memory: 2020  grad_norm: 1.9086  loss: 0.4307  loss_rpn_cls: 0.0202  loss_rpn_bbox: 0.0288  loss_cls: 0.1911  acc: 95.3125  loss_bbox: 0.1905
# 12/02 23:03:32 - mmengine - INFO - Epoch(train) [12][1100/1221]  lr: 2.0000e-04  eta: 0:00:22  time: 0.1903  data_time: 0.0073  memory: 2019  grad_norm: 1.7341  loss: 0.3749  loss_rpn_cls: 0.0181  loss_rpn_bbox: 0.0297  loss_cls: 0.1646  acc: 92.6270  loss_bbox: 0.1625
# 12/02 23:03:42 - mmengine - INFO - Epoch(train) [12][1150/1221]  lr: 2.0000e-04  eta: 0:00:13  time: 0.1921  data_time: 0.0077  memory: 2020  grad_norm: 1.7627  loss: 0.3683  loss_rpn_cls: 0.0173  loss_rpn_bbox: 0.0234  loss_cls: 0.1604  acc: 95.8008  loss_bbox: 0.1672
# 12/02 23:03:51 - mmengine - INFO - Epoch(train) [12][1200/1221]  lr: 2.0000e-04  eta: 0:00:03  time: 0.1865  data_time: 0.0069  memory: 2020  grad_norm: 1.7980  loss: 0.3831  loss_rpn_cls: 0.0165  loss_rpn_bbox: 0.0248  loss_cls: 0.1669  acc: 96.7773  loss_bbox: 0.1749
# 12/02 23:03:55 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_coco_20251202_221758
# 12/02 23:03:55 - mmengine - INFO - Saving checkpoint at 12 epochs
# FasterRCNN(
#   (data_preprocessor): DetDataPreprocessor()
#   (backbone): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}
#   (neck): FPN(
#     (lateral_convs): ModuleList(
#       (0): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): ConvModule(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): ConvModule(
#         (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (3): ConvModule(
#         (conv): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (fpn_convs): ModuleList(
#       (0-3): 4 x ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   init_cfg={'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
#   (rpn_head): RPNHead(
#     (loss_cls): CrossEntropyLoss(avg_non_ignore=False)
#     (loss_bbox): L1Loss()
#     (rpn_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (rpn_cls): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#     (rpn_reg): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#   )
#   init_cfg={'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
#   (roi_head): StandardRoIHead(
#     (bbox_roi_extractor): SingleRoIExtractor(
#       (roi_layers): ModuleList(
#         (0): RoIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         (1): RoIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         (2): RoIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         (3): RoIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#       )
#     )
#     (bbox_head): Shared2FCBBoxHead(
#       (loss_cls): CrossEntropyLoss(avg_non_ignore=False)
#       (loss_bbox): L1Loss()
#       (fc_cls): Linear(in_features=1024, out_features=11, bias=True)
#       (fc_reg): Linear(in_features=1024, out_features=40, bias=True)
#       (shared_convs): ModuleList()
#       (shared_fcs): ModuleList(
#         (0): Linear(in_features=12544, out_features=1024, bias=True)
#         (1): Linear(in_features=1024, out_features=1024, bias=True)
#       )
#       (cls_convs): ModuleList()
#       (cls_fcs): ModuleList()
#       (reg_convs): ModuleList()
#       (reg_fcs): ModuleList()
#       (relu): ReLU(inplace=True)
#     )
#     init_cfg=[{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
#   )
# )
