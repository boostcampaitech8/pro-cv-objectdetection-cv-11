# %%
import os

os.environ["WANDB_DIR"] = "/tmp/user2_wandb"
os.environ["WANDB_CACHE_DIR"] = "/tmp/user2_wandb_cache"
os.environ["WANDB_CONFIG_DIR"] = "/tmp/user2_wandb_config"

import wandb
wandb.login()
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# True

# %%
api = wandb.Api()
me = api.viewer

print("Username:", me.username)
print("Teams:", me.teams)
# Out:
# Username: kkhs4988
# Teams: ['kkhs4988', 'cv_11']

# %%
# 모듈 import
import pandas as pd
from collections import Counter
from IPython.display import display

from mmengine.config import Config
from mmengine.runner import Runner
from mmdet.registry import DATASETS
from mmdet.utils import register_all_modules

# %%
# custom 설정
classes = ("General trash", "Paper", "Paper pack", "Metal", "Glass",
           "Plastic", "Styrofoam", "Plastic bag", "Battery", "Clothing")

root = "../../dataset/"
train_ann = "folds/train_fold0.json"
val_ann   = "folds/val_fold0.json"
test_ann  = "test.json"

# config file 들고오기
cfg = Config.fromfile("configs/my_model/cascade_rcnn_swin_tiny.py")
# cfg = Config.fromfile("configs/my_model/cascade_rcnn_swin_large.py")

register_all_modules(init_default_scope=True)
cfg.default_scope = "mmdet"


########################################################
# 1) Train / Val / Test dataset 구성
########################################################
for ds_key, ann_path in [
    ("train_dataloader", train_ann),
    ("val_dataloader",   val_ann),
    ("test_dataloader",  test_ann),
]:
    if ds_key not in cfg:
        continue

    ds = cfg[ds_key]["dataset"] if "dataset" in cfg[ds_key] else cfg[ds_key]
    ds.metainfo = dict(classes=classes)
    ds.data_root = root
    ds.ann_file = ann_path
    ds.data_prefix = dict(img="")


# dataloader batch 설정
cfg.train_dataloader.batch_size = 1
cfg.train_dataloader.num_workers = 4
cfg.val_dataloader.batch_size = 2
cfg.val_dataloader.num_workers = 2
cfg.test_dataloader.batch_size = 1
cfg.test_dataloader.num_workers = 2


########################################################
# 2) Augmentation pipeline
########################################################
train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations', with_bbox=True),
    dict(type='RandomFlip', prob=[0.5, 0.15], direction=['horizontal', 'vertical']),
    dict(type='MinIoURandomCrop', min_ious=[0.4, 0.5, 0.6, 0.7], min_crop_size=0.3),
    dict(
        type='Albu',
        transforms=[
            dict(
                type='OneOf',
                transforms=[
                    dict(type='RandomBrightnessContrast', p=1.0),
                    dict(type='HueSaturationValue', p=1.0),
                    dict(type='CLAHE', p=1.0),
                    dict(type='RGBShift', p=1.0),
                ],
                p=0.5
            ),
            dict(
                type='OneOf',
                transforms=[
                    dict(type='GaussNoise', p=1.0),
                    dict(type='GaussianBlur', p=1.0),
                    dict(type='Blur', p=1.0),
                ],
                p=0.2
            ),
            dict(
                type='OneOf',
                transforms=[
                    dict(type='ShiftScaleRotate', rotate_limit=10, p=1.0),
                    dict(type='RandomRotate90', p=1.0),
                ],
                p=0.2
            ),
        ],
        bbox_params=dict(
            type='BboxParams',
            format='pascal_voc',
            label_fields=['gt_bboxes_labels', 'gt_ignore_flags'],
            min_visibility=0.0,
            filter_lost_elements=True
        ),
        keymap={'img': 'image', 'gt_bboxes': 'bboxes'},
        skip_img_without_anno=True
    ),
    dict(
    type='RandomChoiceResize',
    scales=[(800, 800), (1024, 1024), (1200, 1200)],
    keep_ratio=True
    ),
    dict(type='PackDetInputs')
]
val_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='Resize', scale=(1024, 1024), keep_ratio=True),
    dict(type='LoadAnnotations', with_bbox=True),
    dict(type='PackDetInputs')
]
tta_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(
        type='MultiScaleFlipAug',
        # --- Multi-Scale TTA ---
        scales=[
            (1024, 1024),  # baseline
            (800, 800),   # COCO 공식 cascade scale
            (1200, 1200),   # 더 큰 객체 대응
        ],
        flip=True,  # 좌우 flip TTA
        transforms=[
            dict(type='Resize', keep_ratio=True),
            dict(type='PackDetInputs')
        ]
    ),
]

cfg.test_dataloader.dataset.pipeline = tta_pipeline
cfg.train_dataloader.dataset.pipeline = train_pipeline
cfg.val_dataloader.dataset.pipeline = val_pipeline


########################################################
# 3) Validation 활성화
########################################################
cfg.val_evaluator = dict(
    type="CocoMetric",
    ann_file=root + val_ann,
    metric=["bbox"],
    classwise=True     # 클래스별 mAP도 출력 가능
)

cfg.val_cfg = dict(type="ValLoop")
cfg.test_cfg = dict(type="TestLoop")

# 매 epoch마다 validation
cfg.train_cfg.max_epochs = 18
cfg.train_cfg.val_interval = 1



########################################################
# 4) Backbone 클래스 수 수정
########################################################
for i in range(3):
    cfg.model.roi_head.bbox_head[i].num_classes = len(classes)


########################################################
# 5) Optimizer (AdamW)
########################################################
cfg.optim_wrapper = dict(
    type='AmpOptimWrapper',
    optimizer=dict(
        type='AdamW',
        lr=0.00005,
        weight_decay=0.05,
        betas=(0.9, 0.999),
    ),
    paramwise_cfg=dict(custom_keys={'backbone': dict(lr_mult=0.1)}),
    clip_grad=dict(max_norm=35, norm_type=2),
)


########################################################
# 6) LR Scheduler
########################################################
cfg.param_scheduler = [
    dict(type='LinearLR', start_factor=0.001, by_epoch=False, begin=0, end=100),
    dict(
        type='CosineAnnealingLR',
        by_epoch=True,
        begin=0,
        end=cfg.train_cfg["max_epochs"],
        eta_min=1e-6,
    )
]


########################################################
# 7) Checkpoint 저장 방식 → mAP 기반 Top3 자동 저장
########################################################
cfg.default_hooks["checkpoint"] = dict(
    type="CheckpointHook",
    interval=1,
    max_keep_ckpts=3,
    save_best="coco/bbox_mAP",  # mAP 기준 best 저장
    rule="greater",             # 값이 클수록 좋음
)

# 저장 파일명 포맷 (epoch 포함)
cfg.work_dir = "./work_dirs/cascade_rcnn_swin_tiny_last"


########################################################
# 8) W&B 설정
########################################################
vis_backends = [
    dict(type='LocalVisBackend'),
    dict(
        type='WandbVisBackend',
        init_kwargs=dict(
            project='cv_11_OD',
            entity='cv_11',
            name='cascade_swin_tiny_last'
        )
    )
]

cfg.visualizer = dict(
    type='DetLocalVisualizer',
    vis_backends=vis_backends,
    name='visualizer'
)

cfg.log_processor = dict(type='LogProcessor', window_size=50, by_epoch=True)
cfg.device = "cuda"

# %%
# dataset summarization 확인
train_ds_cfg = cfg.train_dataloader.dataset
train_ds = DATASETS.build(train_ds_cfg)

def summarize_dataset(ds):
    ds.full_init()
    num_images = len(ds)
    classes = list(ds.metainfo.get("classes", []))

    counts = Counter()
    for i in range(num_images):
        info = ds.get_data_info(i)
        for inst in info.get("instances", []):
            lbl = inst.get("bbox_label", None)
            if lbl is not None:
                counts[lbl] += 1

    df = pd.DataFrame({
        "category": [f"{i} [{c}]" for i, c in enumerate(classes)],
        "count": [counts.get(i, 0) for i in range(len(classes))]
    })

    print(f"\n [Info] CocoDataset Train dataset with number of images {num_images}, and instance counts:")
    display(df)

summarize_dataset(train_ds)
# Out:
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
#
#  [Info] CocoDataset Train dataset with number of images 3914, and instance counts:
#             category  count
# 0  0 [General trash]   3161
# 1          1 [Paper]   5115
# 2     2 [Paper pack]    706
# 3          3 [Metal]    769
# 4          4 [Glass]    835
# 5        5 [Plastic]   2350
# 6      6 [Styrofoam]   1026
# 7    7 [Plastic bag]   4151
# 8        8 [Battery]    143
# 9       9 [Clothing]    377

# %%
# 모델 학습
runner = Runner.from_cfg(cfg)
runner.train()
# Out:
# 12/10 18:56:08 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 874761115
#     GPU 0: Tesla V100-SXM2-32GB
#     CUDA_HOME: None
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 2.1.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.0+cu118
#     OpenCV: 4.7.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 874761115
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 12/10 18:56:09 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'data/coco/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=1,
#         max_keep_ckpts=3,
#         rule='greater',
#         save_best='coco/bbox_mAP',
#         type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# device = 'cuda'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# model = dict(
#     backbone=dict(
#         convert_weights=True,
#         depths=[
#             2,
#             2,
#             18,
#             2,
#         ],
#         drop_path_rate=0.3,
#         embed_dims=192,
#         init_cfg=dict(
#             checkpoint=
#             '/data/ephemeral/home/kkhs/mmdetection/pretrained/swin_large_patch4_window7_224_22k.pth',
#             type='Pretrained'),
#         mlp_ratio=4,
#         num_heads=[
#             6,
#             12,
#             24,
#             48,
#         ],
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         patch_norm=True,
#         qkv_bias=True,
#         type='SwinTransformer',
#         window_size=7,
#         with_cp=True),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_size_divisor=1,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             192,
#             384,
#             768,
#             1536,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=10,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=10,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=10,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='CascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.05),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=True,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='CascadeRCNN')
# optim_wrapper = dict(
#     clip_grad=dict(max_norm=35, norm_type=2),
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=5e-05, type='AdamW', weight_decay=0.05),
#     paramwise_cfg=dict(custom_keys=dict(backbone=dict(lr_mult=0.1))),
#     type='AmpOptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=100, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=18,
#         eta_min=1e-06,
#         type='CosineAnnealingLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='test.json',
#         backend_args=None,
#         data_prefix=dict(img=''),
#         data_root='../../dataset/',
#         metainfo=dict(
#             classes=(
#                 'General trash',
#                 'Paper',
#                 'Paper pack',
#                 'Metal',
#                 'Glass',
#                 'Plastic',
#                 'Styrofoam',
#                 'Plastic bag',
#                 'Battery',
#                 'Clothing',
#             )),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1024,
#                 1024,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='data/coco/annotations/instances_val2017.json',
#     backend_args=None,
#     format_only=False,
#     metric='bbox',
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=18, type='EpochBasedTrainLoop', val_interval=1)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=1,
#     dataset=dict(
#         ann_file='folds/train_fold0.json',
#         backend_args=None,
#         data_prefix=dict(img=''),
#         data_root='../../dataset/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'General trash',
#                 'Paper',
#                 'Paper pack',
#                 'Metal',
#                 'Glass',
#                 'Plastic',
#                 'Styrofoam',
#                 'Plastic bag',
#                 'Battery',
#                 'Clothing',
#             )),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 direction=[
#                     'horizontal',
#                     'vertical',
#                 ],
#                 prob=[
#                     0.5,
#                     0.15,
#                 ],
#                 type='RandomFlip'),
#             dict(
#                 min_crop_size=0.3,
#                 min_ious=[
#                     0.4,
#                     0.5,
#                     0.6,
#                     0.7,
#                 ],
#                 type='MinIoURandomCrop'),
#             dict(
#                 bbox_params=dict(
#                     filter_lost_elements=True,
#                     format='pascal_voc',
#                     label_fields=[
#                         'gt_bboxes_labels',
#                         'gt_ignore_flags',
#                     ],
#                     min_visibility=0.0,
#                     type='BboxParams'),
#                 keymap=dict(gt_bboxes='bboxes', img='image'),
#                 skip_img_without_anno=True,
#                 transforms=[
#                     dict(
#                         p=0.5,
#                         transforms=[
#                             dict(p=1.0, type='RandomBrightnessContrast'),
#                             dict(p=1.0, type='HueSaturationValue'),
#                             dict(p=1.0, type='CLAHE'),
#                             dict(p=1.0, type='RGBShift'),
#                         ],
#                         type='OneOf'),
#                     dict(
#                         p=0.2,
#                         transforms=[
#                             dict(p=1.0, type='GaussNoise'),
#                             dict(p=1.0, type='GaussianBlur'),
#                             dict(p=1.0, type='Blur'),
#                         ],
#                         type='OneOf'),
#                     dict(
#                         p=0.2,
#                         transforms=[
#                             dict(
#                                 p=1.0,
#                                 rotate_limit=10,
#                                 type='ShiftScaleRotate'),
#                             dict(p=1.0, type='RandomRotate90'),
#                         ],
#                         type='OneOf'),
#                 ],
#                 type='Albu'),
#             dict(
#                 keep_ratio=True,
#                 scales=[
#                     (
#                         1333,
#                         800,
#                     ),
#                     (
#                         1600,
#                         960,
#                     ),
#                     (
#                         1024,
#                         640,
#                     ),
#                 ],
#                 type='RandomChoiceResize'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=2,
#     dataset=dict(
#         ann_file='folds/val_fold0.json',
#         backend_args=None,
#         data_prefix=dict(img=''),
#         data_root='../../dataset/',
#         metainfo=dict(
#             classes=(
#                 'General trash',
#                 'Paper',
#                 'Paper pack',
#                 'Metal',
#                 'Glass',
#                 'Plastic',
#                 'Styrofoam',
#                 'Plastic bag',
#                 'Battery',
#                 'Clothing',
#             )),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1024,
#                 1024,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='../../dataset/folds/val_fold0.json',
#     classwise=True,
#     metric=[
#         'bbox',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 entity='cv_11',
#                 name='cascade_swin_large_last',
#                 project='cv_11_OD'),
#             type='WandbVisBackend'),
#     ])
# work_dir = './work_dirs/cascade_rcnn_swin_large_last'
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/data/ephemeral/home/kkhs/mmdetection/work_dirs/cascade_rcnn_swin_large_last/20251210_185607/vis_data/wandb/run-20251210_185615-yflahl62</code>
# Syncing run <strong><a href='https://wandb.ai/cv_11/cv_11_OD/runs/yflahl62' target="_blank">cascade_swin_large_last</a></strong> to <a href='https://wandb.ai/cv_11/cv_11_OD' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/cv_11/cv_11_OD' target="_blank">https://wandb.ai/cv_11/cv_11_OD</a>
#  View run at <a href='https://wandb.ai/cv_11/cv_11_OD/runs/yflahl62' target="_blank">https://wandb.ai/cv_11/cv_11_OD/runs/yflahl62</a>
# 12/10 18:56:27 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 12/10 18:56:27 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.reduction.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.reduction.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.reduction.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.reduction.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.reduction.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.reduction.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.weight:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.bias:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.bias:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.bias:lr_mult=0.1
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:lr=5e-06
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:weight_decay=0.05
# 12/10 18:56:28 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:lr_mult=0.1
# ...
# 12/10 19:19:30 - mmengine - INFO - Epoch(train)  [1][3150/3914]  base_lr: 5.0000e-05 lr: 5.0000e-06  eta: 8:10:55  time: 0.4528  data_time: 0.0041  memory: 5079  grad_norm: 11.1331  loss: 0.7602  loss_rpn_cls: 0.0427  loss_rpn_bbox: 0.0268  s0.loss_cls: 0.2396  s0.acc: 98.6328  s0.loss_bbox: 0.1455  s1.loss_cls: 0.1059  s1.acc: 97.2656  s1.loss_bbox: 0.1132  s2.loss_cls: 0.0408  s2.acc: 97.8516  s2.loss_bbox: 0.0458
# 12/10 19:19:52 - mmengine - INFO - Epoch(train)  [1][3200/3914]  base_lr: 5.0000e-05 lr: 5.0000e-06  eta: 8:10:40  time: 0.4439  data_time: 0.0041  memory: 5035  grad_norm: 14.6226  loss: 0.8643  loss_rpn_cls: 0.0714  loss_rpn_bbox: 0.0411  s0.loss_cls: 0.2685  s0.acc: 95.5078  s0.loss_bbox: 0.1447  s1.loss_cls: 0.1223  s1.acc: 92.5781  s1.loss_bbox: 0.1143  s2.loss_cls: 0.0515  s2.acc: 94.5312  s2.loss_bbox: 0.0505
# 12/10 19:20:15 - mmengine - INFO - Epoch(train)  [1][3250/3914]  base_lr: 5.0000e-05 lr: 5.0000e-06  eta: 8:10:33  time: 0.4525  data_time: 0.0040  memory: 5074  grad_norm: 18.0980  loss: 0.7516  loss_rpn_cls: 0.0448  loss_rpn_bbox: 0.0306  s0.loss_cls: 0.2349  s0.acc: 81.4453  s0.loss_bbox: 0.1325  s1.loss_cls: 0.1073  s1.acc: 86.7188  s1.loss_bbox: 0.1085  s2.loss_cls: 0.0435  s2.acc: 93.1641  s2.loss_bbox: 0.0496
# 12/10 19:20:37 - mmengine - INFO - Epoch(train)  [1][3300/3914]  base_lr: 5.0000e-05 lr: 5.0000e-06  eta: 8:10:30  time: 0.4562  data_time: 0.0043  memory: 5052  grad_norm: 10.8532  loss: 0.8631  loss_rpn_cls: 0.0447  loss_rpn_bbox: 0.0398  s0.loss_cls: 0.2703  s0.acc: 98.0469  s0.loss_bbox: 0.1583  s1.loss_cls: 0.1200  s1.acc: 99.4141  s1.loss_bbox: 0.1293  s2.loss_cls: 0.0481  s2.acc: 94.1406  s2.loss_bbox: 0.0525
# 12/10 19:21:00 - mmengine - INFO - Epoch(train)  [1][3350/3914]  base_lr: 5.0000e-05 lr: 5.0000e-06  eta: 8:10:11  time: 0.4417  data_time: 0.0039  memory: 5036  grad_norm: 11.4273  loss: 0.6975  loss_rpn_cls: 0.0440  loss_rpn_bbox: 0.0288  s0.loss_cls: 0.2155  s0.acc: 87.1094  s0.loss_bbox: 0.1236  s1.loss_cls: 0.0967  s1.acc: 92.5781  s1.loss_bbox: 0.1032  s2.loss_cls: 0.0391  s2.acc: 96.2891  s2.loss_bbox: 0.0464
# 12/10 19:21:22 - mmengine - INFO - Epoch(train)  [1][3400/3914]  base_lr: 5.0000e-05 lr: 5.0000e-06  eta: 8:09:53  time: 0.4416  data_time: 0.0041  memory: 4963  grad_norm: 10.6390  loss: 0.7687  loss_rpn_cls: 0.0498  loss_rpn_bbox: 0.0305  s0.loss_cls: 0.2411  s0.acc: 98.2422  s0.loss_bbox: 0.1360  s1.loss_cls: 0.1082  s1.acc: 97.2656  s1.loss_bbox: 0.1144  s2.loss_cls: 0.0416  s2.acc: 98.4375  s2.loss_bbox: 0.0472
# 12/10 19:21:44 - mmengine - INFO - Epoch(train)  [1][3450/3914]  base_lr: 5.0000e-05 lr: 5.0000e-06  eta: 8:09:33  time: 0.4411  data_time: 0.0041  memory: 5043  grad_norm: 10.8459  loss: 0.8873  loss_rpn_cls: 0.0626  loss_rpn_bbox: 0.0414  s0.loss_cls: 0.2870  s0.acc: 95.7031  s0.loss_bbox: 0.1616  s1.loss_cls: 0.1228  s1.acc: 94.3359  s1.loss_bbox: 0.1136  s2.loss_cls: 0.0491  s2.acc: 94.5312  s2.loss_bbox: 0.0492
# 12/10 19:22:05 - mmengine - INFO - Epoch(train)  [1][3500/3914]  base_lr: 5.0000e-05 lr: 5.0000e-06  eta: 8:09:07  time: 0.4341  data_time: 0.0040  memory: 5011  grad_norm: 15.2479  loss: 0.7368  loss_rpn_cls: 0.0543  loss_rpn_bbox: 0.0319  s0.loss_cls: 0.2356  s0.acc: 97.6562  s0.loss_bbox: 0.1268  s1.loss_cls: 0.1024  s1.acc: 95.3125  s1.loss_bbox: 0.0995  s2.loss_cls: 0.0413  s2.acc: 97.2656  s2.loss_bbox: 0.0450
# 12/10 19:22:28 - mmengine - INFO - Epoch(train)  [1][3550/3914]  base_lr: 5.0000e-05 lr: 5.0000e-06  eta: 8:08:54  time: 0.4472  data_time: 0.0043  memory: 5048  grad_norm: 11.5699  loss: 0.8409  loss_rpn_cls: 0.0528  loss_rpn_bbox: 0.0427  s0.loss_cls: 0.2485  s0.acc: 94.5312  s0.loss_bbox: 0.1563  s1.loss_cls: 0.1101  s1.acc: 91.0156  s1.loss_bbox: 0.1250  s2.loss_cls: 0.0464  s2.acc: 88.0859  s2.loss_bbox: 0.0592
# 12/10 19:22:50 - mmengine - INFO - Epoch(train)  [1][3600/3914]  base_lr: 5.0000e-05 lr: 5.0000e-06  eta: 8:08:37  time: 0.4437  data_time: 0.0040  memory: 5046  grad_norm: 9.9686  loss: 0.6291  loss_rpn_cls: 0.0272  loss_rpn_bbox: 0.0214  s0.loss_cls: 0.1860  s0.acc: 95.3125  s0.loss_bbox: 0.1034  s1.loss_cls: 0.0936  s1.acc: 94.7266  s1.loss_bbox: 0.1010  s2.loss_cls: 0.0423  s2.acc: 94.9219  s2.loss_bbox: 0.0542
# 12/10 19:23:13 - mmengine - INFO - Epoch(train)  [1][3650/3914]  base_lr: 5.0000e-05 lr: 5.0000e-06  eta: 8:08:26  time: 0.4514  data_time: 0.0042  memory: 5032  grad_norm: inf  loss: 0.7014  loss_rpn_cls: 0.0419  loss_rpn_bbox: 0.0265  s0.loss_cls: 0.2101  s0.acc: 97.0703  s0.loss_bbox: 0.1316  s1.loss_cls: 0.0986  s1.acc: 95.8984  s1.loss_bbox: 0.1055  s2.loss_cls: 0.0413  s2.acc: 94.7266  s2.loss_bbox: 0.0460
# 12/10 19:23:35 - mmengine - INFO - Epoch(train)  [1][3700/3914]  base_lr: 5.0000e-05 lr: 5.0000e-06  eta: 8:08:15  time: 0.4501  data_time: 0.0041  memory: 4999  grad_norm: 10.6682  loss: 0.7345  loss_rpn_cls: 0.0404  loss_rpn_bbox: 0.0252  s0.loss_cls: 0.2373  s0.acc: 96.4844  s0.loss_bbox: 0.1202  s1.loss_cls: 0.1121  s1.acc: 93.9453  s1.loss_bbox: 0.1027  s2.loss_cls: 0.0474  s2.acc: 94.9219  s2.loss_bbox: 0.0493
# 12/10 19:23:57 - mmengine - INFO - Epoch(train)  [1][3750/3914]  base_lr: 5.0000e-05 lr: 5.0000e-06  eta: 8:07:59  time: 0.4459  data_time: 0.0044  memory: 5043  grad_norm: 10.2822  loss: 0.7291  loss_rpn_cls: 0.0457  loss_rpn_bbox: 0.0298  s0.loss_cls: 0.2225  s0.acc: 96.8750  s0.loss_bbox: 0.1310  s1.loss_cls: 0.1018  s1.acc: 97.8516  s1.loss_bbox: 0.1055  s2.loss_cls: 0.0433  s2.acc: 93.3594  s2.loss_bbox: 0.0495
# 12/10 19:24:19 - mmengine - INFO - Epoch(train)  [1][3800/3914]  base_lr: 5.0000e-05 lr: 5.0000e-06  eta: 8:07:39  time: 0.4406  data_time: 0.0042  memory: 4862  grad_norm: 10.2421  loss: 0.6563  loss_rpn_cls: 0.0309  loss_rpn_bbox: 0.0268  s0.loss_cls: 0.1920  s0.acc: 96.4844  s0.loss_bbox: 0.1169  s1.loss_cls: 0.0879  s1.acc: 95.3125  s1.loss_bbox: 0.1065  s2.loss_cls: 0.0397  s2.acc: 94.5312  s2.loss_bbox: 0.0554
# 12/10 19:24:41 - mmengine - INFO - Epoch(train)  [1][3850/3914]  base_lr: 5.0000e-05 lr: 5.0000e-06  eta: 8:07:09  time: 0.4301  data_time: 0.0045  memory: 4924  grad_norm: 13.0994  loss: 0.7397  loss_rpn_cls: 0.0443  loss_rpn_bbox: 0.0319  s0.loss_cls: 0.2315  s0.acc: 79.2969  s0.loss_bbox: 0.1317  s1.loss_cls: 0.1012  s1.acc: 85.9375  s1.loss_bbox: 0.1053  s2.loss_cls: 0.0411  s2.acc: 91.4062  s2.loss_bbox: 0.0526
# 12/10 19:25:03 - mmengine - INFO - Epoch(train)  [1][3900/3914]  base_lr: 5.0000e-05 lr: 5.0000e-06  eta: 8:06:52  time: 0.4450  data_time: 0.0045  memory: 5023  grad_norm: 10.5535  loss: 0.7351  loss_rpn_cls: 0.0350  loss_rpn_bbox: 0.0228  s0.loss_cls: 0.2337  s0.acc: 99.2188  s0.loss_bbox: 0.1226  s1.loss_cls: 0.1095  s1.acc: 99.6094  s1.loss_bbox: 0.1110  s2.loss_cls: 0.0485  s2.acc: 99.6094  s2.loss_bbox: 0.0520
# 12/10 19:25:09 - mmengine - INFO - Exp name: cascade_rcnn_swin_large_20251210_185607
# 12/10 19:25:09 - mmengine - INFO - Saving checkpoint at 1 epochs
# 12/10 19:25:51 - mmengine - INFO - Epoch(val)  [1][ 50/485]    eta: 0:02:45  time: 0.3803  data_time: 0.0087  memory: 5006
# 12/10 19:26:10 - mmengine - INFO - Epoch(val)  [1][100/485]    eta: 0:02:26  time: 0.3781  data_time: 0.0047  memory: 4150
# 12/10 19:26:29 - mmengine - INFO - Epoch(val)  [1][150/485]    eta: 0:02:06  time: 0.3780  data_time: 0.0045  memory: 4150
# 12/10 19:26:48 - mmengine - INFO - Epoch(val)  [1][200/485]    eta: 0:01:47  time: 0.3786  data_time: 0.0048  memory: 4150
# 12/10 19:27:07 - mmengine - INFO - Epoch(val)  [1][250/485]    eta: 0:01:28  time: 0.3782  data_time: 0.0045  memory: 4150
# 12/10 19:27:26 - mmengine - INFO - Epoch(val)  [1][300/485]    eta: 0:01:10  time: 0.3789  data_time: 0.0047  memory: 4150
# 12/10 19:27:45 - mmengine - INFO - Epoch(val)  [1][350/485]    eta: 0:00:51  time: 0.3778  data_time: 0.0044  memory: 4150
# 12/10 19:28:04 - mmengine - INFO - Epoch(val)  [1][400/485]    eta: 0:00:32  time: 0.3785  data_time: 0.0045  memory: 4150
# 12/10 19:28:23 - mmengine - INFO - Epoch(val)  [1][450/485]    eta: 0:00:13  time: 0.3782  data_time: 0.0045  memory: 4150
# 12/10 19:28:36 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.41s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.98s).
# Accumulating evaluation results...
# DONE (t=0.89s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.196
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.365
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.196
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.237
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.349
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.349
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.349
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.020
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.116
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.408
# 12/10 19:28:41 - mmengine - INFO -
# +---------------+-------+--------+--------+-------+-------+-------+
# | category      | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +---------------+-------+--------+--------+-------+-------+-------+
# | General trash | 0.101 | 0.199  | 0.09   | 0.001 | 0.049 | 0.161 |
# | Paper         | 0.118 | 0.312  | 0.07   | 0.058 | 0.02  | 0.15  |
# | Paper pack    | 0.251 | 0.394  | 0.305  | 0.0   | 0.054 | 0.325 |
# | Metal         | 0.271 | 0.417  | 0.335  | 0.0   | 0.017 | 0.349 |
# | Glass         | 0.196 | 0.401  | 0.173  | 0.0   | 0.006 | 0.234 |
# | Plastic       | 0.186 | 0.355  | 0.174  | 0.0   | 0.047 | 0.23  |
# | Styrofoam     | 0.163 | 0.368  | 0.121  | nan   | 0.015 | 0.196 |
# | Plastic bag   | 0.286 | 0.535  | 0.268  | 0.0   | 0.033 | 0.335 |
# | Battery       | 0.19  | 0.286  | 0.228  | nan   | nan   | 0.19  |
# | Clothing      | 0.197 | 0.384  | 0.193  | nan   | 0.0   | 0.204 |
# +---------------+-------+--------+--------+-------+-------+-------+
# 12/10 19:28:41 - mmengine - INFO - bbox_mAP_copypaste: 0.196 0.365 0.196 0.008 0.027 0.237
# 12/10 19:28:41 - mmengine - INFO - Epoch(val) [1][485/485]    coco/General trash_precision: 0.1010  coco/Paper_precision: 0.1180  coco/Paper pack_precision: 0.2510  coco/Metal_precision: 0.2710  coco/Glass_precision: 0.1960  coco/Plastic_precision: 0.1860  coco/Styrofoam_precision: 0.1630  coco/Plastic bag_precision: 0.2860  coco/Battery_precision: 0.1900  coco/Clothing_precision: 0.1970  coco/bbox_mAP: 0.1960  coco/bbox_mAP_50: 0.3650  coco/bbox_mAP_75: 0.1960  coco/bbox_mAP_s: 0.0080  coco/bbox_mAP_m: 0.0270  coco/bbox_mAP_l: 0.2370  data_time: 0.0050  time: 0.3781
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 3
#       1 # 모델 학습
#       2 runner = Runner.from_cfg(cfg)
# ----> 3 runner.train()
#
# File ~/py310/lib/python3.10/site-packages/mmengine/runner/runner.py:1777, in Runner.train(self)
#    1773 # Maybe compile the model according to options in self.cfg.compile
#    1774 # This must be called **AFTER** model has been wrapped.
#    1775 self._maybe_compile('train_step')
# -> 1777 model = self.train_loop.run()  # type: ignore
#    1778 self.call_hook('after_run')
#    1779 return model
#
# File ~/py310/lib/python3.10/site-packages/mmengine/runner/loops.py:105, in EpochBasedTrainLoop.run(self)
#     100     self._decide_current_val_interval()
#     101     if (self.runner.val_loop is not None
#     102             and self._epoch >= self.val_begin
#     103             and (self._epoch % self.val_interval == 0
#     104                  or self._epoch == self._max_epochs)):
# --> 105         self.runner.val_loop.run()
#     107 self.runner.call_hook('after_train')
#     108 return self.runner.model
#
# File ~/py310/lib/python3.10/site-packages/mmengine/runner/loops.py:388, in ValLoop.run(self)
#     385     loss_dict = _parse_losses(self.val_loss, 'val')
#     386     metrics.update(loss_dict)
# --> 388 self.runner.call_hook('after_val_epoch', metrics=metrics)
#     389 self.runner.call_hook('after_val')
#     390 return metrics
#
# File ~/py310/lib/python3.10/site-packages/mmengine/runner/runner.py:1839, in Runner.call_hook(self, fn_name, **kwargs)
#    1837 if hasattr(hook, fn_name):
#    1838     try:
# -> 1839         getattr(hook, fn_name)(self, **kwargs)
#    1840     except TypeError as e:
#    1841         raise TypeError(f'{e} in {hook}') from None
#
# File ~/py310/lib/python3.10/site-packages/mmengine/hooks/checkpoint_hook.py:361, in CheckpointHook.after_val_epoch(self, runner, metrics)
#     356     runner.logger.warning(
#     357         'Since `metrics` is an empty dict, the behavior to save '
#     358         'the best checkpoint will be skipped in this evaluation.')
#     359     return
# --> 361 self._save_best_checkpoint(runner, metrics)
#
# File ~/py310/lib/python3.10/site-packages/mmengine/hooks/checkpoint_hook.py:560, in CheckpointHook._save_best_checkpoint(self, runner, metrics)
#     554         self.best_ckpt_path_dict[
#     555             key_indicator] = self.file_backend.join_path(  # type: ignore # noqa: E501
#     556                 self.out_dir, best_ckpt_name)
#     557         runner.message_hub.update_info(
#     558             runtime_best_ckpt_key,
#     559             self.best_ckpt_path_dict[key_indicator])
# --> 560     runner.save_checkpoint(
#     561         self.out_dir,
#     562         filename=best_ckpt_name,
#     563         file_client_args=self.file_client_args,
#     564         save_optimizer=False,
#     565         save_param_scheduler=False,
#     566         meta=meta,
#     567         by_epoch=False,
#     568         backend_args=self.backend_args)
#     569     runner.logger.info(
#     570         f'The best checkpoint with {best_score:0.4f} {key_indicator} '
#     571         f'at {cur_time} {cur_type} is saved to {best_ckpt_name}.')
#     573 # save checkpoint again to update the best_score and best_ckpt stored
#     574 # in message_hub because the checkpoint saved in `after_train_epoch`
#     575 # or `after_train_iter` stage only keep the previous best checkpoint
#     576 # not the current best checkpoint which causes the current best
#     577 # checkpoint can not be removed when resuming training.
#
# File ~/py310/lib/python3.10/site-packages/mmengine/dist/utils.py:427, in master_only.<locals>.wrapper(*args, **kwargs)
#     424 @functools.wraps(func)
#     425 def wrapper(*args, **kwargs):
#     426     if is_main_process():
# --> 427         return func(*args, **kwargs)
#
# File ~/py310/lib/python3.10/site-packages/mmengine/runner/runner.py:2271, in Runner.save_checkpoint(self, out_dir, filename, file_client_args, save_optimizer, save_param_scheduler, meta, by_epoch, backend_args)
#    2268             checkpoint['param_schedulers'].append(state_dict)
#    2270 self.call_hook('before_save_checkpoint', checkpoint=checkpoint)
# -> 2271 save_checkpoint(
#    2272     checkpoint,
#    2273     filepath,
#    2274     file_client_args=file_client_args,
#    2275     backend_args=backend_args)
#
# File ~/py310/lib/python3.10/site-packages/mmengine/runner/checkpoint.py:793, in save_checkpoint(checkpoint, filename, file_client_args, backend_args)
#     791 with io.BytesIO() as f:
#     792     torch.save(checkpoint, f)
# --> 793     file_backend.put(f.getvalue(), filename)
#
# File ~/py310/lib/python3.10/site-packages/mmengine/fileio/backends/local_backend.py:78, in LocalBackend.put(self, obj, filepath)
#      76 mmengine.mkdir_or_exist(osp.dirname(filepath))
#      77 with open(filepath, 'wb') as f:
# ---> 78     f.write(obj)
#
# OSError: [Errno 28] No space left on device

# %%
# !nvidia-smi --query-compute-apps=pid,process_name,used_memory --format=csv
# Out:
# pid, process_name, used_gpu_memory [MiB]
# 971666, [Not Found], 3068 MiB
# 1051891, [Not Found], 29374 MiB

# %%
# !ps -o cmd= -p 1051891
